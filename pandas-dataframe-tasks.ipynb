# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
# Out:
# C:\Users\final solution\AppData\Local\Temp\ipykernel_6396\4080736814.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
dataframe1=pd.DataFrame({"Name":["anu","vinu","manu","anju","arun","varun","manju","neethu","amrutha","amith"],"Age":[27,32,33,24,31,28,25,26,29,30],
"Gender":["F","M","M","F","M","M","F","F","F","M"]})
dataframe1
# Out:
#       Name  Age Gender
# 0      anu   27      F
# 1     vinu   32      M
# 2     manu   33      M
# 3     anju   24      F
# 4     arun   31      M
# 5    varun   28      M
# 6    manju   25      F
# 7   neethu   26      F
# 8  amrutha   29      F
# 9    amith   30      M

# %%
dataframe1["Occupation"]=["Programmer","Manager","Analyst","Manager","Analyst","Programmer","Analyst","Analyst","Programmer","Programmer"]
dataframe1
# Out:
#       Name  Age Gender  Occupation
# 0      anu   27      F  Programmer
# 1     vinu   32      M     Manager
# 2     manu   33      M     Analyst
# 3     anju   24      F     Manager
# 4     arun   31      M     Analyst
# 5    varun   28      M  Programmer
# 6    manju   25      F     Analyst
# 7   neethu   26      F     Analyst
# 8  amrutha   29      F  Programmer
# 9    amith   30      M  Programmer

# %%
dataframe1.sort_values(by=["Age"],ascending=False)
# Out:
#       Name  Age Gender  Occupation
# 2     manu   33      M     Analyst
# 1     vinu   32      M     Manager
# 4     arun   31      M     Analyst
# 9    amith   30      M  Programmer
# 8  amrutha   29      F  Programmer
# 5    varun   28      M  Programmer
# 0      anu   27      F  Programmer
# 7   neethu   26      F     Analyst
# 6    manju   25      F     Analyst
# 3     anju   24      F     Manager

# %%
print(dataframe1[dataframe1["Age"]>=30])
# Out:
#     Name  Age Gender  Occupation
# 1   vinu   32      M     Manager
# 2   manu   33      M     Analyst
# 4   arun   31      M     Analyst
# 9  amith   30      M  Programmer
